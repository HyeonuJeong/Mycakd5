# %%
#네이버 검색api 예제는 블로그를 비롯 전문 자료까지 호출방법이 동일함으로 blog검색으로 대표예제만 올림

# %%
import os
import re
import sys
import urllib.request
client_id = "m2uAWbFvq8bLW5HJHYPU"
client_secret = "tuoULrAN6G"
encText = urllib.parse.quote("빅데이터")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    res=response_body.decode('utf-8')
    print(re.sub('[<>{}br*,+]','', res))
else:
    print("Error Code:" + rescode)
# Out:
# "lastBuildDate": "Fi 11 Fe 2022 15:42:53 0900"
# "total": 1018935
# "stat": 1
# "display": 10
# "items": [
#
# "title": "빅데이터/학원 기초과정부터 배워요"
# "link": "https:\/\/log.nave.com\/ssohi07?Rediect=Log&logNo=222638093778"
# "desciption": "특히 데이터를 수집하여 통계를 작성하고 이를 통해 다양한 일을 할 수 있는 분야가 유망했습니다. 저는 이 분야가 마음에 들어서 빅데이터/학원을 등록하게 되었습니다. 빅데이터/ 분야는 앞으로도 전망이... "
# "loggename": "너와 wedding의 연결고리"
# "loggelink": "https://log.nave.com/ssohi07"
# "postdate": "20220203"
#
#
#
# "title": "빅데이터/분석기사인강 통한 시험 준비로 필기 합격 기대!"
# "link": "https:\/\/log.nave.com\/waiting25?Rediect=Log&logNo=222641084425"
# "desciption": "빅데이터/분석기사는 자료(데이터) 경제 활성화에 따라 대량의 정형. 비정형 자료를 분석 미례를 예측하고 최적화 모형을 제시하는 실무자로서 전 세계적으로 빅데이터/가 미래성장동력으로 인식되어져가고... "
# "loggename": "스터디채널 공식블로그"
# "loggelink": "https://log.nave.com/waiting25"
# "postdate": "20220207"
#
#
#
# "title": "빅데이터/학원 실기 위주의 학습"
# "link": "https:\/\/log.nave.com\/lackhole68?Rediect=Log&logNo=222596181315"
# "desciption": "빅데이터/는 말 그대로 방대한 양의 데이터 양을 말하는건데 갈수록 정보통신 기술이 발전하고 사용자가 많아 지기 때문에 갈수록 빅데이터/에 의존하는 기업이 많아지는 만큼 장래성이 밝다고 느껴져서... "
# "loggename": "김용식 문학서재"
# "loggelink": "https://log.nave.com/lackhole68"
# "postdate": "20211215"
#
#
#
# "title": "빅데이터/전문가자격증 공부 순서는 이렇게!"
# "link": "https:\/\/log.nave.com\/eshan97?Rediect=Log&logNo=222560079238"
# "desciption": "위와 같은 방법을 써서 빅데이터/전문가자격증 과정 20일차였던 데이터 내용 보기까지 딱 정해진 시점에 다 완강할 수 있었습니다. 마지막 수업 종료 창이 뜨자마자 하나를 끝낸 것 같아 마음이 놓였어요.... "
# "loggename": "Eunsung log"
# "loggelink": "https://log.nave.com/eshan97"
# "postdate": "20211107"
#
#
#
# "title": "빅데이터/학원 기초부터 응용까지 확실하게!"
# "link": "https:\/\/log.nave.com\/oneu?Rediect=Log&logNo=222626786580"
# "desciption": "그래서 빅데이터/ 분야로 취업할 때 가점을 해준다는 ADSP 데이터 분석 준전문가 자격증을 준비하게 됬어요. 남자친구도 바로 전문가 자격증보다는 준전문가부터 무리하지말고 차분히 준비해보라고 하더라구요.... "
# "loggename": "알콩달콩 장씨네 블로그"
# "loggelink": "https://log.nave.com/oneu"
# "postdate": "20220120"
#
#
#
# "title": "빅데이터/학원 실무습득의 원천은?"
# "link": "https:\/\/log.nave.com\/ssoyeon12?Rediect=Log&logNo=222614203698"
# "desciption": "참고로 빅데이터/는 양이 매우 많고 증가 속도가 빠르며 종류가 매우 다양한 데이터를 말하는데요! 이러한 빅데이터/는 너무 방대하여 기존의 데이터 처리 소프트웨어로는 관리할 수가 없어요! 다만 이 방대한... "
# "loggename": "요롱일상"
# "loggelink": "https://log.nave.com/ssoyeon12"
# "postdate": "20220106"
#
#
#
# "title": "빅데이터/분석기사 어렵지 않았던 교육과정"
# "link": "https:\/\/log.nave.com\/unilena?Rediect=Log&logNo=222617949376"
# "desciption": "대규모의 데이터가 늘어나 빅데이터/가 됐다고 해요. 과거에 비해 데이터의 양이 엄청나게 증폭했고 데이터의 종류도 다양해지면서 이런 데이터를 분석하여 사람들의 행동과 생각 의견 등을 예측하는 게... "
# "loggename": "Awesome days."
# "loggelink": "https://log.nave.com/unilena"
# "postdate": "20220110"
#
#
#
# "title": "빅데이터/전문가 요즘 필요한 이유"
# "link": "https:\/\/log.nave.com\/iasi?Rediect=Log&logNo=222603148149"
# "desciption": "저는 특히 놀랐던 것이 정부에서도 설문조사를 실시하고 유의미한 결과를 얻어내기 위해 데이터 분석 전문가를 등용하고 있다는 사실이었어요! 빅데이터/전문가 시험과목은 어렵지 않은 것이... "
# "loggename": "PRONG"
# "loggelink": "https://log.nave.com/iasi"
# "postdate": "20211223"
#
#
#
# "title": "빅데이터/자격증 준비 과정 자세하게 공개"
# "link": "https:\/\/log.nave.com\/dpffjdtoki?Rediect=Log&logNo=222603040666"
# "desciption": "매일매일 쌓여가는 데이터의 양을 굉장하다고 합니다. 이 빅데이터/는 정리가 되어 있는 것도 아니에요. 어디서나 찾아볼 수 있는데 있던데 그걸 정리하고 데이터화 시키고 분석하고 하는 것이 전문가가 하는... "
# "loggename": "tokitoki7"
# "loggelink": "https://log.nave.com/dpffjdtoki"
# "postdate": "20211223"
#
#
#
# "title": "빅데이터/ 분석기사 필기 출제기준 맞춤 수험서"
# "link": "https:\/\/log.nave.com\/akodien?Rediect=Log&logNo=222496826999"
# "desciption": "빅데이터/분석기사 필기 준비하는 사람으로서 성안당의 출제기준 맞춤 수험서가 괜찮다는 생각이... 그 전에 빅데이터/분석기사에 대해 궁금해 하실 사람이 많을 것 같아서 짧게나마 자격증 소개를 드려보도로... "
# "loggename": "더나은 공식블로그"
# "loggelink": "https://log.nave.com/akodien"
# "postdate": "20210906"
#
#
# ]

# %%
#[과제] 2개 이상의 카테고리에 대하여 데이터 수집

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "xUCzXK76sez26412vcLf"
client_secret = "oCZNcdIe3A"
# encText = urllib.parse.quote("빅데이터")
query = urllib.parse.quote(input("검색 질의: "))

idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=('Title','Link','Description'))

for start_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/news?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index)
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, "", items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            web_df.loc[idx] = [title, link, description]
            idx += 1        
    else:
        print("Error Code:" + rescode)
web_df
# Out:
# 검색 질의: 코로나
#                                             Title  \
# 0                 SK실트론, 3년 연속 정기 헌혈…혈액 수급난 극복 앞장
# 1    현대바이오 &quot;먹는 코로나 치료제, 오미크론 99% 이상 억제&quot;
# 2                     인천시, 창업에서 재도전까지 소상공인 맞춤형 지원
# 3                  대구시, 재택치료자 동거가족 위한 '가족안심숙소' 운영
# 4                   코로나19에도 경남 농수산식품 수출 작년 13% 증가
# ..                                            ...
# 995                         전남도, 14일부터 노바백스 백신 접종
# 996                 아시아나항공, 인천~하와이 재운항 기념 프로모션 실시
# 997                      [사설]대선 후보 등록, 시작된 유권자 선택
# 998         현대바이오 코로나 경구제, 임상2상서 오미크론 99%이상 억제 확인
# 999              “2월 말부터 면역저하자, 요양병원·시설 입소자 4차접종”
#
#                                                   Link  \
# 0    https://www.ebn.co.kr/news/view/1519508/?sc=Naver
# 1    http://www.digitaltoday.co.kr/news/articleView...
# 2    https://news.naver.com/main/read.naver?mode=LS...
# 3    https://ilyo.co.kr/?ac=article_view&entry_id=4...
# 4    http://www.weeklytrade.co.kr/news/view.html?se...
# ..                                                 ...
# 995  https://news.naver.com/main/read.naver?mode=LS...
# 996  https://www.ebn.co.kr/news/view/1519471/?sc=Naver
# 997  http://www.joongdo.co.kr/web/view.php?key=2022...
# 998  http://www.getnews.co.kr/news/articleView.html...
# 999  https://news.naver.com/main/read.naver?mode=LS...
#
#                                            Description
# 0    SK실트론은 코로나19 발병 첫 해인 2020년, 지역사회 안전망(Safety Ne...
# 1    현대바이오는 코로나19 경구용 항바이러스제 'CP-COV03'가 오미크론 증식을 9...
# 2    인천시는 코로나19 장기화 등 불확실한 경영환경에 어려움을 겪고 있는 소상공인을 위...
# 3    - 5곳 총 65객실 확보…1박당 2만원, 최장 7일 이용 가능 - 이영희 시민건강...
# 4    밝혔다.코로나19로 인한 세계적인 경기침체 속에서도 국가별 전략 품목을 선정하고, ...
# ..                                                 ...
# 995  전남도는 코로나19 예방을 위해 14일부터 노바백스 백신 접종을 시작한다고 밝혔다....
# 996  아시아나항공 관계자는 &quot;입국 시 백신 접종 완료 영문 증명서와 출발 이전 ...
# 997  코로나19가 초래한 전대미문의 위기는 자영업자와 소상공인을 벼랑 끝으로 몰고 있고,...
# 998  현대바이오의 신종 코로나바이러스 감염증(코로나19) 경구용 항바이러스제 CP-COV...
# 999  2월 말부터 면역 저하자와 요양병원·시설 환자·입소자에 대한 코로나19 백신 4차 ...
#
# [1000 rows x 3 columns]

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "xUCzXK76sez26412vcLf"
client_secret = "oCZNcdIe3A"
# encText = urllib.parse.quote("빅데이터")
query = urllib.parse.quote(input("검색 질의: "))

idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=('Title','Link','Description'))

for start_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/kin?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index)
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, "", items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            web_df.loc[idx] = [title, link, description]
            idx += 1        
    else:
        print("Error Code:" + rescode)
web_df
# Out:
# 검색 질의: 코로나
#              Title                                               Link  \
# 0       코로나 감기 구별법  https://kin.naver.com/qna/detail.naver?d1id=7&...
# 1         코로나 얼굴 열  https://kin.naver.com/qna/detail.naver?d1id=7&...
# 2        코로나 음성 문자  https://kin.naver.com/qna/detail.naver?d1id=7&...
# 3        코로나 감염 확률  https://kin.naver.com/qna/detail.naver?d1id=7&...
# 4      해외여행 코로나 겨리  https://kin.naver.com/qna/detail.naver?d1id=9&...
# ..             ...                                                ...
# 995         위드 코로나  https://kin.naver.com/qna/detail.naver?d1id=3&...
# 996         코로나인가요  https://kin.naver.com/qna/detail.naver?d1id=7&...
# 997    위드코로나가 뭐예요?  https://kin.naver.com/qna/detail.naver?d1id=3&...
# 998  육군훈련소 코로나 화생방  https://kin.naver.com/qna/detail.naver?d1id=6&...
# 999    코로나인지 알려주세요  https://kin.naver.com/qna/detail.naver?d1id=7&...
#
#                                            Description
# 0    코로나랑 감기 구별법 알려주세요 시간이 없어서 코로나 검사를 하기는 좀 그런데 최근...
# 1    ... 없는데 코로나일까요? 아니면 평소에 생활패턴이 불규칙하고... 보니까 요즘엔...
# 2    아빠랑 코로나 검사 같이 받으러 갔는데 아빠는 음성 문자가 왔는데 전 안... #코...
# 3    ... 옷으로는 코로나 안 걸리나요? 2. 나갔다와서 손은 씻었는데 팔같은 다른 부...
# 4    곧 체코로 여행을 가는데 한국으로 다시 돌아올때 코로나... 그리고 코로나에 걸리면...
# ..                                                 ...
# 995  ... 위드코로나로 질문 할것이 있는데 위드코로나가되면 대면 예배가능한가요?  네 ...
# 996  한 2틀전부터 목이 아프고 콧물이 나오다기 지금 살짝 어지럽고 오늘 설사하고 기침도...
# 997  위드코로나가 뭐예요? [위드 코로나 뜻] 강력한 변이 바이러스 출현, 돌파감염 등으...
# 998  ... 육군훈련소 코로나 심각한가요? 가면 꼭 코로나 검사해야하나요? 그리고 격리한...
# 999  저희 엄마네 회사 사장님이 코로나 양성이 나왔다고 오늘... 지금 코로나 검사하러 ...
#
# [1000 rows x 3 columns]

# %%
https://openweathermap.org/api

# %%
[과제] 아래사항에 유의하여 OpenWeatherMap 날씨정보를 웹 API로 가져와서 출력하세요

https://openweathermap.org/api 사이트에서 Current Weather data에 대한 API doc 내용을 파악
개발자 등록을 하고 API 키 발급 받음(https://home.openweathermap.org/users/sign_up)
New Account 등록 후 API Keys라는 탭에서 API Key 확인 가능
기본적으로 유료 사이트이지만 현재 날씨, 5일까지의 날씨는 무료로 사용할 수 있음(단 1분에 60번만 호출 가능)
서울, 토쿄, 뉴욕의 날씨를 가져오는 프로그램 작성(text로 가져와서 json으로 변환하여 일차 출력)
cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
가져올 정보 : 도시별 날씨(description), 최저 기온(temp_min), 최고 기온(temp_max), 습도(humidity), 기압(pressure), 풍속(speed)
기온 데이터는 켈빈 온도로 되어 있으며 섭씨 온도로 변환해서 출력
json 포멧으로 출력 데이터를 아래와 같이 가독력 있게 출력(소수점 2번째에서 반올림 처리)

도시 = Seoul | 날씨 = broken clouds | 최저 기온 = -1.0 2 | 최고 기온 = 2.0 2 | 습도 = 74 | 기압 = 1023 | 풍속 = 0.5

[팀과제] 관심 주제에 대한 사이트 API 학습 및 실사례 소개

# %%
import requests
import json
key='550197b851fda7e91a395fe5d049bf29'
cities = ["Seoul ,KR","Tokyo,JP","New York,US"]
apikey="http://api.openweathermap.org/data/2.5/weather?q={city}&APPID={key}"
def k2C(k):
    return k - 273.15

for name in cities:
    url = apikey.format(city=name, key=key)
    print(url)
    res = requests.get(url)
    data = json.loads(res.text)
    print("**도시 = ", data["name"])
    print("| 날씨 = ", data["weather"][0]["description"])
    print("| 최저 기온 = ", k2C(data["main"]["temp_min"]))
    print("| 최고 기온 = ", k2C(data["main"]["temp_max"]))
    print("| 습도 = ", data["main"]["humidity"])
    print("| 기압 = ", data["main"]["pressure"])
    print("| 풍향 = ", data["wind"]["deg"])
    print("| 풍속 = ", data["wind"]["speed"])
    print(" ")
# Out:
# http://api.openweathermap.org/data/2.5/weather?q=Seoul ,KR&APPID=550197b851fda7e91a395fe5d049bf29
# **도시 =  Seoul
# | 날씨 =  clear sky
# | 최저 기온 =  0.2300000000000182
# | 최고 기온 =  3.730000000000018
# | 습도 =  70
# | 기압 =  1021
# | 풍향 =  190
# | 풍속 =  0.51
#
# http://api.openweathermap.org/data/2.5/weather?q=Tokyo,JP&APPID=550197b851fda7e91a395fe5d049bf29
# **도시 =  Tokyo
# | 날씨 =  light rain
# | 최저 기온 =  3.0600000000000023
# | 최고 기온 =  6.420000000000016
# | 습도 =  71
# | 기압 =  1018
# | 풍향 =  20
# | 풍속 =  7.2
#
# http://api.openweathermap.org/data/2.5/weather?q=New York,US&APPID=550197b851fda7e91a395fe5d049bf29
# **도시 =  New York
# | 날씨 =  overcast clouds
# | 최저 기온 =  -3.6499999999999773
# | 최고 기온 =  -0.839999999999975
# | 습도 =  66
# | 기압 =  1018
# | 풍향 =  20
# | 풍속 =  6.17
