# %%
import pandas as pd

df=pd.read_csv('C:/1차data/3.19.csv',encoding='cp949')
df
# Out:
#         고객번호  성별  연령대  거주지역  1번품목구매비율(%)  2번품목구매비율(%)  3번품목구매비율(%)  \
# 0          1   1    5     1         2.86        27.70        66.92
# 1          2   1    5     0         3.64        36.73        53.35
# 2          3   1    5     0         4.47        95.53         0.00
# 3          4   0    5     1         2.72        26.13        66.48
# 4          6   0    5     3         4.99        45.59        40.38
# ...      ...  ..  ...   ...          ...          ...          ...
# 18861  19333   0    1     0        15.53        55.08         0.00
# 18862  19334   1    2     3        13.88        66.70         0.00
# 18863  19335   0    2     0        16.72        53.31         0.00
# 18864  19336   0    2     1        10.66        30.64        54.74
# 18865  19337   1    1     1         6.46        93.54         0.00
#
#        4번품목구매비율(%)  경쟁사이용횟수  멤버쉽보유  온라인이용횟수  1기구매비율(%)  2기구매비율(%)  3기구매비율(%)  \
# 0             2.52     15.0    0.0      0.0      11.46      14.63      13.22
# ...

# %%
sdf=df[df['분기증감확인']==1]
sdf
# Out:
#         고객번호  성별  연령대  거주지역  1번품목구매비율(%)  2번품목구매비율(%)  3번품목구매비율(%)  \
# 4          6   0    5     3         4.99        45.59        40.38
# 5          7   0    5     1         0.84        26.09        71.95
# 6          8   1    5     0         5.44        67.60        15.55
# 7          9   0    5     0         2.17        45.28        40.83
# 9         11   1    5     0         2.17        42.03        52.77
# ...      ...  ..  ...   ...          ...          ...          ...
# 18858  19330   1    4     0         8.15        49.31        26.98
# 18859  19331   0    5     0         4.36        75.13        20.50
# 18863  19335   0    2     0        16.72        53.31         0.00
# 18864  19336   0    2     1        10.66        30.64        54.74
# 18865  19337   1    1     1         6.46        93.54         0.00
#
#        4번품목구매비율(%)  경쟁사이용횟수  멤버쉽보유  온라인이용횟수  1기구매비율(%)  2기구매비율(%)  3기구매비율(%)  \
# 4             9.04      0.0    0.0      0.0       8.86      13.33      16.02
# ...

# %%
stdf=pd.read_csv('C:/1차data/고객속성추가수정.csv')
stdf.columns

pdf=stdf[['고객번호','총구매액', '총구매액.1', '총구매액.2',
       '총구매액.3', '총구매액.4', '총구매액.5', '총구매액.6', '총구매액.7']]
pdf
# Out:
#         고객번호        총구매액      총구매액.1      총구매액.2      총구매액.3      총구매액.4  \
# 0          1   8995824.0  11108203.0  12181088.0  20694107.0   9408643.0
# 1          2  13898280.0  10506625.0  16767689.0   6279623.0  18691374.0
# 2          3    297954.0    564936.0    732292.0    349742.0    282483.0
# 3          4   1288767.0   3844763.0   2750419.0   1616792.0   1757018.0
# 4          6   2131469.0   3209003.0   3573895.0   2616896.0   3660327.0
# ...      ...         ...         ...         ...         ...         ...
# 18861  19333    603348.0    941484.0    653268.0    403911.0    860360.0
# 18862  19334    820744.0   2787328.0   2909975.0   2500765.0   1719235.0
# 18863  19335    922771.0   2866847.0   2621277.0   1811375.0   2224410.0
# 18864  19336    442432.0   3421816.0   3570613.0   5220264.0   2929416.0
# 18865  19337     16257.0     74136.0    681537.0    678884.0    540429.0
#
#           총구매액.5      총구매액.6     총구매액.7
# 0      9217176.0   8792000.0  4375707.0
# ...

# %%
df=pd.merge(sdf,pdf, on='고객번호',how='left')
df
# Out:
#        고객번호  성별  연령대  거주지역  1번품목구매비율(%)  2번품목구매비율(%)  3번품목구매비율(%)  \
# 0         6   0    5     3         4.99        45.59        40.38
# 1         7   0    5     1         0.84        26.09        71.95
# 2         8   1    5     0         5.44        67.60        15.55
# 3         9   0    5     0         2.17        45.28        40.83
# 4        11   1    5     0         2.17        42.03        52.77
# ...     ...  ..  ...   ...          ...          ...          ...
# 8231  19330   1    4     0         8.15        49.31        26.98
# 8232  19331   0    5     0         4.36        75.13        20.50
# 8233  19335   0    2     0        16.72        53.31         0.00
# 8234  19336   0    2     1        10.66        30.64        54.74
# 8235  19337   1    1     1         6.46        93.54         0.00
#
#       4번품목구매비율(%)  경쟁사이용횟수  멤버쉽보유  ...  8기구매비율(%)  분기증감확인        총구매액  \
# 0            9.04      0.0    0.0  ...       9.64       1   2131469.0
# ...

# %%
df.describe().to_csv('C:/1차data/증가고객만.csv',encoding='cp949')
