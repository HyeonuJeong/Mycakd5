# %%
import re
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn import svm
from sklearn.svm import SVC
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import Binarizer
from sklearn.metrics import accuracy_score, precision_score , recall_score , confusion_matrix
from sklearn.model_selection import GridSearchCV
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\hyeonu\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# # 상품동적변수 라벨링

# %%
# %%time
import pandas as pd
import warnings
warnings.simplefilter("ignore")
df = pd.read_csv('C:/1차data/상품동적변수라벨링.csv',encoding='cp949')
df
# Out:
# Wall time: 216 ms
#         고객번호  편의품_증감율  편의품_변동율     편의품CV  선매품_증감율  선매품_변동율     선매품CV  전문품_증감율  \
# 0          1       -2        4  0.423231        0        0  0.415863        0
# 1          2        0        0  0.404963        0        0  0.395417        0
# 2          3        0        2  0.355232        0        2  1.945495        0
# 3          4        0        2  0.267522        1        3  0.539876        3
# 4          6        1       11  0.336680        0        0  0.255509        3
# ...      ...      ...      ...       ...      ...      ...       ...      ...
# 18861  19333        0        4  0.531012       -1        5  1.413875        0
# 18862  19334       -1        5  0.710300        1        3  1.111205        0
# 18863  19335        1        5  0.285949        0        2  0.581560        0
# 18864  19336        0        2  1.110957        2        4  0.582518        3
# 18865  19337        2        2  0.842965        1        5  1.734204        0
#
#        전문품_변동율     전문품CV  ...      B_CV  식품_증감율  식품_변동율      식품CV  의류_증감율  \
# 0           12  1.356745  ...  0.468137       0       4  0.373790       0
# 1            6  2.099585  ...  0.937181       0       2  0.289531       0
# 2            0  0.000000  ...  2.645751       0       2  0.468734       0
# 3            3  2.645751  ...  0.445867       0       6  0.346428       0
# 4            7  1.282600  ...  0.026677       1       7  0.359479       0
# ...        ...       ...  ...       ...     ...     ...       ...     ...
# 18861        0  0.000000  ...  0.091328       0       4  0.567128      -1
# 18862        0  0.000000  ...  0.117180      -1       5  0.745829       1
# 18863        0  0.000000  ...  0.025504       1       3  0.311870      -1
# 18864        9  1.398080  ...  2.645751       0       0  1.170780       2
# 18865        0  0.000000  ...  1.716064       2       4  0.805277       0
#
#        의류_변동율      의류CV  생활_증감율  생활_변동율      생활CV
# 0           0  0.116473      -4      10  1.540948
# 1           0  0.558315       0       2  1.108827
# 2           4  2.645751       1       1  0.624040
# 3           2  0.626600      -1       3  0.375034
# 4           2  0.498527       1       7  0.441365
# ...       ...       ...     ...     ...       ...
# 18861       1  2.645751      -1       1  1.395795
# 18862       3  1.256815       0       6  0.691297
# 18863       3  0.625589       1       3  0.608691
# 18864       4  0.619823       4      18  1.381031
# 18865       4  1.983014       1       1  1.105168
#
# [18866 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['고객번호', '편의품_증감율', '편의품_변동율', '편의품CV', '선매품_증감율', '선매품_변동율', '선매품CV',
#        '전문품_증감율', '전문품_변동율', '전문품CV', '기타_증감율', '기타_변동율', '기타CV', 'A증감율',
#        'A변동율', 'A_CV', 'B증감율', 'B변동율', 'B_CV', '식품_증감율', '식품_변동율', '식품CV',
#        '의류_증감율', '의류_변동율', '의류CV', '생활_증감율', '생활_변동율', '생활CV'],
#       dtype='object')

# %%
df=df[['고객번호','편의품_증감율', '편의품_변동율', '편의품CV', '선매품_증감율', '선매품_변동율', '선매품CV',
       '전문품_증감율', '전문품_변동율', '전문품CV', '기타_증감율', '기타_변동율', '기타CV',
      '식품_증감율', '식품_변동율', '식품CV',
       '의류_증감율', '의류_변동율', '의류CV', 
         '생활_증감율', '생활_변동율', '생활CV']]
df
# Out:
#         고객번호  편의품_증감율  편의품_변동율     편의품CV  선매품_증감율  선매품_변동율     선매품CV  전문품_증감율  \
# 0          1       -2        4  0.423231        0        0  0.415863        0
# 1          2        0        0  0.404963        0        0  0.395417        0
# 2          3        0        2  0.355232        0        2  1.945495        0
# 3          4        0        2  0.267522        1        3  0.539876        3
# 4          6        1       11  0.336680        0        0  0.255509        3
# ...      ...      ...      ...       ...      ...      ...       ...      ...
# 18861  19333        0        4  0.531012       -1        5  1.413875        0
# 18862  19334       -1        5  0.710300        1        3  1.111205        0
# 18863  19335        1        5  0.285949        0        2  0.581560        0
# 18864  19336        0        2  1.110957        2        4  0.582518        3
# 18865  19337        2        2  0.842965        1        5  1.734204        0
#
#        전문품_변동율     전문품CV  ...      기타CV  식품_증감율  식품_변동율      식품CV  의류_증감율  \
# 0           12  1.356745  ...  0.491980       0       4  0.373790       0
# 1            6  2.099585  ...  1.196030       0       2  0.289531       0
# 2            0  0.000000  ...  0.000000       0       2  0.468734       0
# 3            3  2.645751  ...  0.615895       0       6  0.346428       0
# 4            7  1.282600  ...  0.237022       1       7  0.359479       0
# ...        ...       ...  ...       ...     ...     ...       ...     ...
# 18861        0  0.000000  ...  0.577843       0       4  0.567128      -1
# 18862        0  0.000000  ...  1.097728      -1       5  0.745829       1
# 18863        0  0.000000  ...  1.239736       1       3  0.311870      -1
# 18864        9  1.398080  ...  0.570862       0       0  1.170780       2
# 18865        0  0.000000  ...  0.000000       2       4  0.805277       0
#
#        의류_변동율      의류CV  생활_증감율  생활_변동율      생활CV
# 0           0  0.116473      -4      10  1.540948
# 1           0  0.558315       0       2  1.108827
# 2           4  2.645751       1       1  0.624040
# 3           2  0.626600      -1       3  0.375034
# 4           2  0.498527       1       7  0.441365
# ...       ...       ...     ...     ...       ...
# 18861       1  2.645751      -1       1  1.395795
# 18862       3  1.256815       0       6  0.691297
# 18863       3  0.625589       1       3  0.608691
# 18864       4  0.619823       4      18  1.381031
# 18865       4  1.983014       1       1  1.105168
#
# [18866 rows x 22 columns]

# %%
# %%time
import pandas as pd
import warnings
warnings.simplefilter("ignore")
df = pd.read_csv('C:/1차data/CV_대분류.csv',encoding='cp949')
df
# Out:
# Wall time: 67 ms
#         고객번호  편의품_CV_S  편의품_CV_C   선매품CV_S   선매품CV_C   전문품CV_S   전문품CV_C  \
# 0          1  0.423231  0.450363  0.415863  0.187114  1.356745  1.247219
# 1          2  0.404963  0.217903  0.395417  0.260345  2.099585  2.094437
# 2          3  0.355232  0.336062  1.945495  1.707825  0.000000  0.000000
# 3          4  0.267522  0.299495  0.539876  0.435087  2.645751  2.645751
# 4          6  0.336680  0.184807  0.255509  0.323405  1.282600  1.058301
# ...      ...       ...       ...       ...       ...       ...       ...
# 18861  19333  0.531012  0.433746  1.413875  1.466643  0.000000  0.000000
# 18862  19334  0.710300  0.680638  1.111205  0.501125  0.000000  0.000000
# 18863  19335  0.285949  0.294746  0.581560  0.482012  0.000000  0.000000
# 18864  19336  1.110957  0.694073  0.582518  0.429805  1.398080  1.376893
# 18865  19337  0.842965  0.709136  1.734204  1.063113  0.000000  0.000000
#
#          기타CV_S    기타CV_C
# 0      0.491980  0.490667
# 1      1.196030  0.864521
# 2      0.000000  0.000000
# 3      0.615895  0.628138
# 4      0.237022  0.351850
# ...         ...       ...
# 18861  0.577843  0.269152
# 18862  1.097728  1.032669
# 18863  1.239736  0.426265
# 18864  0.570862  0.592007
# 18865  0.000000  0.000000
#
# [18866 rows x 9 columns]

# %% [markdown]
# # 세분류라벨링

# %%
# %%time
import pandas as pd
import warnings
warnings.simplefilter("ignore")
df = pd.read_csv('C:/1차data/세분류_CV.csv',encoding='cp949')
df
# Out:
# Wall time: 208 ms
#         고객번호  생활잡화CV_S  생활잡화CV_C   식료품CV_S   식료품CV_C  고급식료품CV_S  고급식료품CV_C  \
# 0          1  1.540948  0.885654  0.373790  0.421108   1.703368   1.551209
# 1          2  1.108827  0.368856  0.289531  0.305696   2.055104   1.707825
# 2          3  0.624040  0.411024  0.468734  0.421179   0.000000   0.000000
# 3          4  0.375034  0.361020  0.346428  0.317770   1.916112   1.707825
# 4          6  0.441365  0.236272  0.359479  0.207556   1.826988   1.835857
# ...      ...       ...       ...       ...       ...        ...        ...
# 18861  19333  1.395795  1.163576  0.567128  0.482240   1.537699   1.557776
# 18862  19334  0.691297  0.559001  0.745829  0.712778   1.313464   1.247219
# 18863  19335  0.608691  0.394258  0.311870  0.302453   1.759287   1.247219
# 18864  19336  1.381031  0.957427  1.170780  0.894427   2.645751   2.645751
# 18865  19337  1.105168  0.793049  0.805277  0.710548   0.000000   0.000000
#
#         기호품CV_S   기호품CV_C  의류잡화CV_S  ...  레저취미CV_S  레저취미CV_C  전자제품CV_S  \
# 0      1.066678  0.402776  0.116473  ...  1.628962  1.495363  2.013893
# 1      1.018558  0.419877  0.558315  ...  0.509951  0.621027  1.202233
# 2      0.313032  0.324466  2.645751  ...  0.000000  0.000000  2.645751
# 3      0.631667  0.627913  0.626600  ...  1.620152  1.290994  0.000000
# 4      1.295754  1.085715  0.498527  ...  2.315618  1.707825  0.000000
# ...         ...       ...       ...  ...       ...       ...       ...
# 18861  0.648542  0.534734  2.645751  ...  2.645751  2.645751  0.000000
# 18862  1.212919  0.981428  1.256815  ...  0.978332  0.577350  2.645751
# 18863  0.511910  0.425245  0.625589  ...  1.385985  0.847319  0.000000
# 18864  2.022526  1.835857  0.619823  ...  0.000000  0.000000  0.000000
# 18865  1.107086  0.735818  1.983014  ...  2.645751  2.645751  2.645751
#
#        전자제품CV_C  도서음반CV_S  도서음반CV_C  차량용품CV_S  차량용품CV_C   사치품CV_S   사치품CV_C
# 0      1.742835  0.000000  0.000000  0.000000  0.000000  1.356745  1.247219
# 1      0.721569  0.000000  0.000000  0.000000  0.000000  2.099585  2.094437
# 2      2.645751  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3      0.000000  0.000000  0.000000  0.000000  0.000000  2.645751  2.645751
# 4      0.000000  0.000000  0.000000  0.000000  0.000000  1.282600  1.058301
# ...         ...       ...       ...       ...       ...       ...       ...
# 18861  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 18862  2.645751  1.270026  1.376893  2.645751  2.645751  0.000000  0.000000
# 18863  0.000000  0.872815  0.810077  1.640665  1.376893  0.000000  0.000000
# 18864  0.000000  0.000000  0.000000  0.000000  0.000000  1.398080  1.376893
# 18865  2.645751  0.000000  0.000000  2.227156  1.707825  0.000000  0.000000
#
# [18866 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['고객번호', '편의품_증감율', '편의품_변동율', '편의품CV', '선매품_증감율', '선매품_변동율', '선매품CV',
#        '전문품_증감율', '전문품_변동율', '전문품CV', '기타_증감율', '기타_변동율', '기타CV', 'A증감율',
#        'A변동율', 'A_CV', 'B증감율', 'B변동율', 'B_CV', '식품_증감율', '식품_변동율', '식품CV',
#        '의류_증감율', '의류_변동율', '의류CV', '생활_증감율', '생활_변동율', '생활CV'],
#       dtype='object')

# %%
df=df[['고객번호','편의품_증감율', '편의품_변동율', '편의품CV', '선매품_증감율', '선매품_변동율', '선매품CV',
       '전문품_증감율', '전문품_변동율', '전문품CV', '기타_증감율', '기타_변동율', '기타CV',
      '식품_증감율', '식품_변동율', '식품CV',
       '의류_증감율', '의류_변동율', '의류CV', 
         '생활_증감율', '생활_변동율', '생활CV']]
df
# Out:
#         고객번호  편의품_증감율  편의품_변동율     편의품CV  선매품_증감율  선매품_변동율     선매품CV  전문품_증감율  \
# 0          1       -2        4  0.423231        0        0  0.415863        0
# 1          2        0        0  0.404963        0        0  0.395417        0
# 2          3        0        2  0.355232        0        2  1.945495        0
# 3          4        0        2  0.267522        1        3  0.539876        3
# 4          6        1       11  0.336680        0        0  0.255509        3
# ...      ...      ...      ...       ...      ...      ...       ...      ...
# 18861  19333        0        4  0.531012       -1        5  1.413875        0
# 18862  19334       -1        5  0.710300        1        3  1.111205        0
# 18863  19335        1        5  0.285949        0        2  0.581560        0
# 18864  19336        0        2  1.110957        2        4  0.582518        3
# 18865  19337        2        2  0.842965        1        5  1.734204        0
#
#        전문품_변동율     전문품CV  ...      기타CV  식품_증감율  식품_변동율      식품CV  의류_증감율  \
# 0           12  1.356745  ...  0.491980       0       4  0.373790       0
# 1            6  2.099585  ...  1.196030       0       2  0.289531       0
# 2            0  0.000000  ...  0.000000       0       2  0.468734       0
# 3            3  2.645751  ...  0.615895       0       6  0.346428       0
# 4            7  1.282600  ...  0.237022       1       7  0.359479       0
# ...        ...       ...  ...       ...     ...     ...       ...     ...
# 18861        0  0.000000  ...  0.577843       0       4  0.567128      -1
# 18862        0  0.000000  ...  1.097728      -1       5  0.745829       1
# 18863        0  0.000000  ...  1.239736       1       3  0.311870      -1
# 18864        9  1.398080  ...  0.570862       0       0  1.170780       2
# 18865        0  0.000000  ...  0.000000       2       4  0.805277       0
#
#        의류_변동율      의류CV  생활_증감율  생활_변동율      생활CV
# 0           0  0.116473      -4      10  1.540948
# 1           0  0.558315       0       2  1.108827
# 2           4  2.645751       1       1  0.624040
# 3           2  0.626600      -1       3  0.375034
# 4           2  0.498527       1       7  0.441365
# ...       ...       ...     ...     ...       ...
# 18861       1  2.645751      -1       1  1.395795
# 18862       3  1.256815       0       6  0.691297
# 18863       3  0.625589       1       3  0.608691
# 18864       4  0.619823       4      18  1.381031
# 18865       4  1.983014       1       1  1.105168
#
# [18866 rows x 22 columns]

# %%
df1=pd.read_csv('C:/1차data/3.22.csv',encoding='cp949')
df1=df1[['고객번호','성별','연령대','거주지역', '경쟁사이용횟수', '멤버쉽보유', '온라인이용횟수','분기증감확인'
         ]]
df=pd.merge(df1,df, on='고객번호',how='left')
df
# Out:
#         고객번호  성별  연령대  거주지역  경쟁사이용횟수  멤버쉽보유  온라인이용횟수  분기증감확인  편의품_CV_S  \
# 0          1   1    5     1       15      0        0       0  0.423231
# 1          2   1    5     0        8      0        0       0  0.404963
# 2          3   1    5     0        0      0        0       0  0.355232
# 3          4   0    5     1        3      0        0       0  0.267522
# 4          6   0    5     3        0      0        0       1  0.336680
# ...      ...  ..  ...   ...      ...    ...      ...     ...       ...
# 18861  19333   0    1     0        0      1        5       0  0.531012
# 18862  19334   1    2     3       30      1        0       0  0.710300
# 18863  19335   0    2     0        0      1        0       1  0.285949
# 18864  19336   0    2     1        0      0        0       1  1.110957
# 18865  19337   1    1     1        0      0        0       1  0.842965
#
#        편의품_CV_C   선매품CV_S   선매품CV_C   전문품CV_S   전문품CV_C    기타CV_S    기타CV_C
# 0      0.450363  0.415863  0.187114  1.356745  1.247219  0.491980  0.490667
# 1      0.217903  0.395417  0.260345  2.099585  2.094437  1.196030  0.864521
# 2      0.336062  1.945495  1.707825  0.000000  0.000000  0.000000  0.000000
# 3      0.299495  0.539876  0.435087  2.645751  2.645751  0.615895  0.628138
# 4      0.184807  0.255509  0.323405  1.282600  1.058301  0.237022  0.351850
# ...         ...       ...       ...       ...       ...       ...       ...
# 18861  0.433746  1.413875  1.466643  0.000000  0.000000  0.577843  0.269152
# 18862  0.680638  1.111205  0.501125  0.000000  0.000000  1.097728  1.032669
# 18863  0.294746  0.581560  0.482012  0.000000  0.000000  1.239736  0.426265
# 18864  0.694073  0.582518  0.429805  1.398080  1.376893  0.570862  0.592007
# 18865  0.709136  1.734204  1.063113  0.000000  0.000000  0.000000  0.000000
#
# [18866 rows x 16 columns]

# %%
cor=df.corr()['분기증감확인'].abs()
cor.sort_values(ascending=False)

# df.corr().abs()>0.5
# Out:
# 분기증감확인      1.000000
# 편의품_CV_C    0.177251
# 편의품_CV_S    0.164386
# 전문품CV_S     0.053363
# 전문품CV_C     0.045246
# 연령대         0.030961
# 선매품CV_S     0.028209
# 기타CV_C      0.026093
# 기타CV_S      0.020932
# 경쟁사이용횟수     0.019390
# 온라인이용횟수     0.017091
# 멤버쉽보유       0.014491
# 성별          0.010664
# 선매품CV_C     0.004459
# 고객번호        0.000697
# 거주지역        0.000018
# Name: 분기증감확인, dtype: float64

# %%
df2=pd.read_csv('C:/1차data/RFM테이블.csv',encoding='cp949')
df=pd.merge(df,df2, on='고객번호',how='left')
df
# Out:
#         고객번호  성별  연령대  거주지역  경쟁사이용횟수  멤버쉽보유  온라인이용횟수  분기증감확인  편의품_CV_S  \
# 0          1   1    5     1       15      0        0       0  0.423231
# 1          2   1    5     0        8      0        0       0  0.404963
# 2          3   1    5     0        0      0        0       0  0.355232
# 3          4   0    5     1        3      0        0       0  0.267522
# 4          6   0    5     3        0      0        0       1  0.336680
# ...      ...  ..  ...   ...      ...    ...      ...     ...       ...
# 18861  19333   0    1     0        0      1        5       0  0.531012
# 18862  19334   1    2     3       30      1        0       0  0.710300
# 18863  19335   0    2     0        0      1        0       1  0.285949
# 18864  19336   0    2     1        0      0        0       1  1.110957
# 18865  19337   1    1     1        0      0        0       1  0.842965
#
#        편의품_CV_C   선매품CV_S   선매품CV_C   전문품CV_S   전문품CV_C    기타CV_S    기타CV_C  \
# 0      0.450363  0.415863  0.187114  1.356745  1.247219  0.491980  0.490667
# 1      0.217903  0.395417  0.260345  2.099585  2.094437  1.196030  0.864521
# 2      0.336062  1.945495  1.707825  0.000000  0.000000  0.000000  0.000000
# 3      0.299495  0.539876  0.435087  2.645751  2.645751  0.615895  0.628138
# 4      0.184807  0.255509  0.323405  1.282600  1.058301  0.237022  0.351850
# ...         ...       ...       ...       ...       ...       ...       ...
# 18861  0.433746  1.413875  1.466643  0.000000  0.000000  0.577843  0.269152
# 18862  0.680638  1.111205  0.501125  0.000000  0.000000  1.097728  1.032669
# 18863  0.294746  0.581560  0.482012  0.000000  0.000000  1.239736  0.426265
# 18864  0.694073  0.582518  0.429805  1.398080  1.376893  0.570862  0.592007
# 18865  0.709136  1.734204  1.063113  0.000000  0.000000  0.000000  0.000000
#
#              총구매액  구매빈도  최근구매일
# 0      80397041.0   979     10
# 1      91717156.0   997      3
# 2       3037160.0  1098     10
# 3      15711888.0   823      2
# 4      22123951.0  1374      2
# ...           ...   ...    ...
# 18861   4339816.0   734      4
# 18862  12106990.0  1916     33
# 18863  15255492.0  1643      2
# 18864  26592233.0   389      7
# 18865   4069296.0  1054      3
#
# [18866 rows x 19 columns]

# %%
X =df.drop(['고객번호','분기증감확인'],axis=1)
y=df[['분기증감확인']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,random_state=10)
X
# Out:
#        성별  연령대  거주지역  경쟁사이용횟수  멤버쉽보유  온라인이용횟수  편의품_CV_S  편의품_CV_C   선매품CV_S  \
# 0       1    5     1       15      0        0  0.423231  0.450363  0.415863
# 1       1    5     0        8      0        0  0.404963  0.217903  0.395417
# 2       1    5     0        0      0        0  0.355232  0.336062  1.945495
# 3       0    5     1        3      0        0  0.267522  0.299495  0.539876
# 4       0    5     3        0      0        0  0.336680  0.184807  0.255509
# ...    ..  ...   ...      ...    ...      ...       ...       ...       ...
# 18861   0    1     0        0      1        5  0.531012  0.433746  1.413875
# 18862   1    2     3       30      1        0  0.710300  0.680638  1.111205
# 18863   0    2     0        0      1        0  0.285949  0.294746  0.581560
# 18864   0    2     1        0      0        0  1.110957  0.694073  0.582518
# 18865   1    1     1        0      0        0  0.842965  0.709136  1.734204
#
#         선매품CV_C   전문품CV_S   전문품CV_C    기타CV_S    기타CV_C        총구매액  구매빈도  \
# 0      0.187114  1.356745  1.247219  0.491980  0.490667  80397041.0   979
# 1      0.260345  2.099585  2.094437  1.196030  0.864521  91717156.0   997
# 2      1.707825  0.000000  0.000000  0.000000  0.000000   3037160.0  1098
# 3      0.435087  2.645751  2.645751  0.615895  0.628138  15711888.0   823
# 4      0.323405  1.282600  1.058301  0.237022  0.351850  22123951.0  1374
# ...         ...       ...       ...       ...       ...         ...   ...
# 18861  1.466643  0.000000  0.000000  0.577843  0.269152   4339816.0   734
# 18862  0.501125  0.000000  0.000000  1.097728  1.032669  12106990.0  1916
# 18863  0.482012  0.000000  0.000000  1.239736  0.426265  15255492.0  1643
# 18864  0.429805  1.398080  1.376893  0.570862  0.592007  26592233.0   389
# 18865  1.063113  0.000000  0.000000  0.000000  0.000000   4069296.0  1054
#
#        최근구매일
# 0         10
# 1          3
# 2         10
# 3          2
# 4          2
# ...      ...
# 18861      4
# 18862     33
# 18863      2
# 18864      7
# 18865      3
#
# [18866 rows x 17 columns]

# %%
# %%time

def est(y_test,pred,pred_proba):
    con=confusion_matrix(y_test,pred)
    acc=accuracy_score(y_test,pred)
    pre=precision_score(y_test,pred)
    rec=recall_score(y_test,pred)
    f1=f1_score(y_test,pred)
    roc=roc_auc_score(y_test,pred_proba)
    print('오차행렬\n',con.round(3))
    print('정확도 :',acc.round(3))
    print('정밀도 :',pre.round(3))
    print('재현율 :',rec.round(3))
    print('f1점수:',f1.round(3))
    print('roc_auc :',roc.round(3))
    print()
    print()
    
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train , y_train)
pred = dt_clf.predict(X_test)
pred_proba = dt_clf.predict_proba(X_test)[:,1]
print('결정트리')
est(y_test,pred,pred_proba)

rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, y_train)
pred = rf_clf.predict(X_test)
pred_proba = rf_clf.predict_proba(X_test)[:,1]
print('랜덤포레스트')
est(y_test,pred,pred_proba)

                                                                  

lr_clf = LogisticRegression()
lr_clf.fit(X_train, y_train)
pred = lr_clf.predict(X_test)
pred_proba = lr_clf.predict_proba(X_test)[:,1]
print('로지스틱회귀')
est(y_test,pred,pred_proba)

lgbm_wrapper = LGBMClassifier(n_estimators=400)
evals = [(X_test,y_test)]
lgbm_wrapper.fit(X_train, y_train, eval_set=evals, verbose=False)
pred = lgbm_wrapper.predict(X_test)
pred_proba = lgbm_wrapper.predict_proba(X_test)[:,1]
print('LGBM')
est(y_test,pred,pred_proba)


evals = [(X_test,y_test)]
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3)
xgb_wrapper.fit(X_train,y_train, early_stopping_rounds = 100, eval_set=evals, eval_metric='logloss', verbose=False)
pred = xgb_wrapper.predict(X_test)
pred_proba = xgb_wrapper.predict_proba(X_test)[:,1]
print('XGB')
est(y_test,pred,pred_proba)


# svm_model = svm.SVC(kernel='linear',probability=True,C=1)
# svm_model.fit(X_train, y_train)
# pred = svm_model.predict(X_test)
# pred_proba = svm_model.predict_proba(X_test)[:,1]
# print('SVM')
# est(y_test,pred,pred_proba)


# k_model = KNeighborsClassifier(n_neighbors=40)
# k_model.fit(X_train,y_train)
# pred = k_model.predict(X_test)
# pred_proba = k_model.predict_proba(X_test)[:,1]
# print('KNN')
# est(y_test,pred,pred_proba)



# lr_clf = LogisticRegression()
# knn_clf = KNeighborsClassifier(n_neighbors=8)
# vo_clf = VotingClassifier( estimators=[('LR',lr_clf),('KNN',knn_clf)] , voting='soft' )
# vo_clf.fit(X_train , y_train)
# pred = vo_clf.predict(X_test)
# pred_proba = vo_clf.predict_proba(X_test)[:,1]
# print('KNN + 로지스틱회귀 앙상블')
# est(y_test,pred,pred_proba)
# Out:
# 결정트리
# 오차행렬
#  [[1261  856]
#  [ 839  818]]
# 정확도 : 0.551
# 정밀도 : 0.489
# 재현율 : 0.494
# f1점수: 0.491
# roc_auc : 0.545
#
#
# 랜덤포레스트
# 오차행렬
#  [[1598  519]
#  [ 954  703]]
# 정확도 : 0.61
# 정밀도 : 0.575
# 재현율 : 0.424
# f1점수: 0.488
# roc_auc : 0.638
#
#
# 로지스틱회귀
# 오차행렬
#  [[2117    0]
#  [1657    0]]
# 정확도 : 0.561
# 정밀도 : 0.0
# 재현율 : 0.0
# f1점수: 0.0
# roc_auc : 0.481
#
#
# LGBM
# 오차행렬
#  [[1510  607]
#  [ 911  746]]
# 정확도 : 0.598
# 정밀도 : 0.551
# 재현율 : 0.45
# f1점수: 0.496
# roc_auc : 0.625
#
#
# XGB
# 오차행렬
#  [[1620  497]
#  [ 997  660]]
# 정확도 : 0.604
# 정밀도 : 0.57
# 재현율 : 0.398
# f1점수: 0.469
# roc_auc : 0.643
#
#
# Wall time: 13 s
