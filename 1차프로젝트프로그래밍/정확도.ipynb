# %%
import re
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn import svm
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import Binarizer
from sklearn.metrics import accuracy_score, precision_score , recall_score , confusion_matrix
from sklearn.model_selection import GridSearchCV
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\hyeonu\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
import pandas as pd

df=pd.read_csv('C:/1차data/3.19.csv',encoding='cp949')
df
# Out:
#         고객번호  성별  연령대  거주지역  1번품목구매비율(%)  2번품목구매비율(%)  3번품목구매비율(%)  \
# 0          1   1    5     1         2.86        27.70        66.92
# 1          2   1    5     0         3.64        36.73        53.35
# 2          3   1    5     0         4.47        95.53         0.00
# 3          4   0    5     1         2.72        26.13        66.48
# 4          6   0    5     3         4.99        45.59        40.38
# ...      ...  ..  ...   ...          ...          ...          ...
# 18861  19333   0    1     0        15.53        55.08         0.00
# 18862  19334   1    2     3        13.88        66.70         0.00
# 18863  19335   0    2     0        16.72        53.31         0.00
# 18864  19336   0    2     1        10.66        30.64        54.74
# 18865  19337   1    1     1         6.46        93.54         0.00
#
#        4번품목구매비율(%)  경쟁사이용횟수  멤버쉽보유  온라인이용횟수  1기구매비율(%)  2기구매비율(%)  3기구매비율(%)  \
# 0             2.52     15.0    0.0      0.0      11.46      14.63      13.22
# 1             6.28      8.0    0.0      0.0      10.30       9.24      16.44
# 2             0.00      0.0    0.0      0.0       9.88      12.45      13.71
# 3             4.67      3.0    0.0      0.0       9.35      14.65      21.83
# 4             9.04      0.0    0.0      0.0       8.86      13.33      16.02
# ...            ...      ...    ...      ...        ...        ...        ...
# 18861        29.39      0.0    1.0      5.0      11.51      11.72      15.37
# 18862        19.42     30.0    1.0      0.0      10.03       9.05       9.48
# 18863        29.97      0.0    1.0      0.0      13.37      13.37      13.17
# 18864         3.96      0.0    0.0      0.0       9.27       7.35       7.48
# 18865         0.00      0.0    0.0      0.0       8.18      12.43      12.43
#
#        4기구매비율(%)  5기구매비율(%)  6기구매비율(%)  7기구매비율(%)  8기구매비율(%)  분기증감확인
# 0          14.90       8.43      10.15      18.56       8.65       0
# 1           6.49      17.57      11.73      16.87      11.36       0
# 2          11.11      14.96      11.62      15.71      10.56       0
# 3          12.53       9.71       9.85      13.69       8.39       0
# 4          11.16      12.32      14.81      13.86       9.64       1
# ...          ...        ...        ...        ...        ...     ...
# 18861       7.99      13.80      15.52      13.97      10.12       0
# 18862      11.36      11.80       7.81      27.53      12.94       0
# 18863       9.74      10.97      17.91      11.52       9.94       1
# 18864      11.51       7.79      19.75      23.40      13.44       1
# 18865      14.14      13.50      11.38      15.87      12.07       1
#
# [18866 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['고객번호', '성별', '연령대', '거주지역', '1번품목구매비율(%)', '2번품목구매비율(%)',
#        '3번품목구매비율(%)', '4번품목구매비율(%)', '경쟁사이용횟수', '멤버쉽보유', '온라인이용횟수',
#        '1기구매비율(%)', '2기구매비율(%)', '3기구매비율(%)', '4기구매비율(%)', '5기구매비율(%)',
#        '6기구매비율(%)', '7기구매비율(%)', '8기구매비율(%)', '분기증감확인', 'A제휴사구매비율(%)',
#        'B제휴사구매비율(%)', 'C제휴사구매비율(%)', 'D번제휴사구매비율(%)'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
stcol=['1번품목구매비율(%)', '2번품목구매비율(%)',
       '3번품목구매비율(%)', '4번품목구매비율(%)',
      '1기구매비율(%)', '2기구매비율(%)', '3기구매비율(%)', '4기구매비율(%)', '5기구매비율(%)',
       '6기구매비율(%)', '7기구매비율(%)', '8기구매비율(%)',
      '경쟁사이용횟수','멤버쉽보유','온라인이용횟수','A제휴사구매비율(%)',
       'B제휴사구매비율(%)', 'C제휴사구매비율(%)', 'D번제휴사구매비율(%)']

for i in stcol:
    sc = StandardScaler()
    sc.fit(df[[i]])
    df[i] = sc.transform(df[[i]])
df
# Out:
#         고객번호  성별  연령대  거주지역  1번품목구매비율(%)  2번품목구매비율(%)  3번품목구매비율(%)  \
# 0          1   1    5     1    -0.630974    -0.755058     1.078629
# 1          2   1    5     0    -0.525165    -0.394411     0.679567
# 2          3   1    5     0    -0.412574     1.953988    -0.889331
# 3          4   0    5     1    -0.649966    -0.817762     1.065689
# 4          6   0    5     3    -0.342034    -0.040554     0.298150
# ...      ...  ..  ...   ...          ...          ...          ...
# 18861  19333   0    1     0     1.087744     0.338465    -0.889331
# 18862  19334   1    2     3     0.863918     0.802553    -0.889331
# 18863  19335   0    2     0     1.249171     0.267773    -0.889331
# 18864  19336   0    2     1     0.427116    -0.637638     0.720444
# 18865  19337   1    1     1    -0.142625     1.874509    -0.889331
#
#        4번품목구매비율(%)   경쟁사이용횟수     멤버쉽보유  ...  4기구매비율(%)  5기구매비율(%)  6기구매비율(%)  \
# 0        -0.835903  3.784157 -0.652472  ...   0.679744  -0.915534  -0.558190
# 1        -0.596377  1.828781 -0.652472  ...  -1.199224   1.146230  -0.195524
# 2        -0.996436 -0.405935 -0.652472  ...  -0.167020   0.557477  -0.220773
# 3        -0.698940  0.432083 -0.652472  ...   0.150237  -0.626797  -0.627051
# 4        -0.420556 -0.405935 -0.652472  ...  -0.155849  -0.038043   0.511444
# ...            ...       ...       ...  ...        ...        ...        ...
# 18861     0.875812 -0.405935  1.068660  ...  -0.864093   0.295809   0.674414
# 18862     0.240687  7.974248  1.068660  ...  -0.111165  -0.155343  -1.095303
# 18863     0.912760 -0.405935  1.068660  ...  -0.473107  -0.342571   1.223004
# 18864    -0.744170 -0.405935 -0.652472  ...  -0.077652  -1.059902   1.645349
# 18865    -0.996436 -0.405935 -0.652472  ...   0.509944   0.228136  -0.275862
#
#        7기구매비율(%)  8기구매비율(%)  분기증감확인  A제휴사구매비율(%)  B제휴사구매비율(%)  C제휴사구매비율(%)  \
# 0       1.083053  -0.543234       0     0.367529    -0.340113     0.040420
# 1       0.744137  -0.027620       0     0.177409    -0.281131    -0.875067
# 2       0.511509  -0.179831       0     0.936198    -0.809546    -0.498028
# 3       0.106415  -0.592702       0    -1.177130     1.397840     0.780628
# 4       0.140507  -0.354873       1    -0.457831    -0.248812     1.744034
# ...          ...        ...     ...          ...          ...          ...
# 18861   0.162567  -0.263547       0    -2.846467     0.000044     0.368281
# 18862   2.881910   0.272996       0     1.003333    -0.811162    -0.645565
# 18863  -0.328760  -0.297794       1     0.808135    -0.639872    -0.476591
# 18864   2.053673   0.368127       1    -0.543583     0.845186    -0.875067
# 18865   0.543596   0.107467       1     0.061192     0.378984    -0.397147
#
#        D번제휴사구매비율(%)
# 0         -0.350180
# 1          0.970125
# 2         -0.350180
# 3         -0.350180
# 4         -0.350180
# ...             ...
# 18861      6.340700
# 18862     -0.350180
# 18863     -0.350180
# 18864      0.815422
# 18865     -0.350180
#
# [18866 rows x 24 columns]

# %%
lst=['성별','연령대','거주지역']

ddf=pd.get_dummies(df[lst[0]])
ddf.columns=['성별1','성별2']
onehot=pd.concat([df,ddf],axis=1)    
onehot

ddf=pd.get_dummies(df[lst[1]])
ddf.columns=['연령대1','연령대2','연령대3','연령대4','연령대5','연령대6']


ddf=pd.get_dummies(df[lst[2]])
ddf.columns=['거주1','거주2','거주3','거주4',]
onehot=pd.concat([onehot,ddf],axis=1)    
onehot
# Out:
#         고객번호  성별  연령대  거주지역  1번품목구매비율(%)  2번품목구매비율(%)  3번품목구매비율(%)  \
# 0          1   1    5     1    -0.630974    -0.755058     1.078629
# 1          2   1    5     0    -0.525165    -0.394411     0.679567
# 2          3   1    5     0    -0.412574     1.953988    -0.889331
# 3          4   0    5     1    -0.649966    -0.817762     1.065689
# 4          6   0    5     3    -0.342034    -0.040554     0.298150
# ...      ...  ..  ...   ...          ...          ...          ...
# 18861  19333   0    1     0     1.087744     0.338465    -0.889331
# 18862  19334   1    2     3     0.863918     0.802553    -0.889331
# 18863  19335   0    2     0     1.249171     0.267773    -0.889331
# 18864  19336   0    2     1     0.427116    -0.637638     0.720444
# 18865  19337   1    1     1    -0.142625     1.874509    -0.889331
#
#        4번품목구매비율(%)   경쟁사이용횟수     멤버쉽보유  ...  A제휴사구매비율(%)  B제휴사구매비율(%)  \
# 0        -0.835903  3.784157 -0.652472  ...     0.367529    -0.340113
# 1        -0.596377  1.828781 -0.652472  ...     0.177409    -0.281131
# 2        -0.996436 -0.405935 -0.652472  ...     0.936198    -0.809546
# 3        -0.698940  0.432083 -0.652472  ...    -1.177130     1.397840
# 4        -0.420556 -0.405935 -0.652472  ...    -0.457831    -0.248812
# ...            ...       ...       ...  ...          ...          ...
# 18861     0.875812 -0.405935  1.068660  ...    -2.846467     0.000044
# 18862     0.240687  7.974248  1.068660  ...     1.003333    -0.811162
# 18863     0.912760 -0.405935  1.068660  ...     0.808135    -0.639872
# 18864    -0.744170 -0.405935 -0.652472  ...    -0.543583     0.845186
# 18865    -0.996436 -0.405935 -0.652472  ...     0.061192     0.378984
#
#        C제휴사구매비율(%)  D번제휴사구매비율(%)  성별1  성별2  거주1  거주2  거주3  거주4
# 0         0.040420     -0.350180    0    1    0    1    0    0
# 1        -0.875067      0.970125    0    1    1    0    0    0
# 2        -0.498028     -0.350180    0    1    1    0    0    0
# 3         0.780628     -0.350180    1    0    0    1    0    0
# 4         1.744034     -0.350180    1    0    0    0    0    1
# ...            ...           ...  ...  ...  ...  ...  ...  ...
# 18861     0.368281      6.340700    1    0    1    0    0    0
# 18862    -0.645565     -0.350180    0    1    0    0    0    1
# 18863    -0.476591     -0.350180    1    0    1    0    0    0
# 18864    -0.875067      0.815422    1    0    0    1    0    0
# 18865    -0.397147     -0.350180    0    1    0    1    0    0
#
# [18866 rows x 30 columns]

# %%
onehot.corr()['분기증감확인']
# Out:
# 고객번호            0.000697
# 성별             -0.010664
# 연령대            -0.030961
# 거주지역            0.000018
# 1번품목구매비율(%)    -0.077652
# 2번품목구매비율(%)    -0.050620
# 3번품목구매비율(%)     0.089658
# 4번품목구매비율(%)    -0.077013
# 경쟁사이용횟수         0.019390
# 멤버쉽보유           0.014491
# 온라인이용횟수         0.017091
# 1기구매비율(%)      -0.282714
# 2기구매비율(%)      -0.049685
# 3기구매비율(%)      -0.048493
# 4기구매비율(%)       0.028228
# 5기구매비율(%)      -0.022266
# 6기구매비율(%)       0.033062
# 7기구매비율(%)       0.020669
# 8기구매비율(%)       0.330984
# 분기증감확인          1.000000
# A제휴사구매비율(%)     0.038448
# B제휴사구매비율(%)    -0.044507
# C제휴사구매비율(%)    -0.047857
# D번제휴사구매비율(%)    0.033186
# 성별1             0.010664
# 성별2            -0.010664
# 거주1            -0.033401
# 거주2             0.050836
# 거주3             0.002540
# 거주4            -0.037469
# Name: 분기증감확인, dtype: float64

# %%
X.columns
# Out:
# Index(['성별1', '성별2', '연령대1', '연령대2', '연령대3', '연령대4', '연령대5', '연령대6', '거주1',
#        '거주2', '거주3', '거주4'],
#       dtype='object')

# %%
# X = df.drop(['고객번호','분기증감확인'],axis=1)
# y=df[['분기증감확인']]
# X = onehot.drop(['1번품목구매비율(%)', '2번품목구매비율(%)', '3번품목구매비율(%)', '4번품목구매비율(%)', '경쟁사이용횟수',
#        '멤버쉽보유', '온라인이용횟수', '1기구매비율(%)', '2기구매비율(%)', '3기구매비율(%)', '4기구매비율(%)',
#        '5기구매비율(%)', '6기구매비율(%)', '7기구매비율(%)', '8기구매비율(%)','고객번호','분기증감확인','성별','연령대','거주지역', '거주1',
#        '거주2', '거주3', '거주4', '연령대1', '연령대2', '연령대3', '연령대4', '연령대5', '연령대6',	'성별1','성별2'],axis=1)

X = onehot.drop(['고객번호','분기증감확인','성별','연령대','거주지역'],axis=1)
y=df[['분기증감확인']]
X
# Out:
#        1번품목구매비율(%)  2번품목구매비율(%)  3번품목구매비율(%)  4번품목구매비율(%)   경쟁사이용횟수     멤버쉽보유  \
columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,random_state=10)

# %%
# %%time
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train , y_train)
dt_pred = dt_clf.predict(X_test)
print('DecisionTreeClassifier 정확도: {0:.3f}'.format(accuracy_score(y_test, dt_pred)))

rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, y_train)
rf_pred = rf_clf.predict(X_test)
print('RandomForestClassifier 정확도: {0:.3f}'.format(accuracy_score(y_test, rf_pred)))
                                                                  

lr_clf = LogisticRegression()
lr_clf.fit(X_train, y_train)
lr_preds = lr_clf.predict(X_test)
print('LogisticRegression 정확도: {:0.3f}'.format(accuracy_score(y_test, lr_preds)))

lgbm_wrapper = LGBMClassifier(n_estimators=400)
evals = [(X_test,y_test)]
lgbm_wrapper.fit(X_train, y_train, eval_set=evals, verbose=False)
preds = lgbm_wrapper.predict(X_test)
print('lgbm 정확도: {:0.3f}'.format(accuracy_score(y_test, preds)))


evals = [(X_test,y_test)]
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3)
xgb_wrapper.fit(X_train,y_train, early_stopping_rounds = 100, eval_set=evals, eval_metric='logloss', verbose=False)
w_preds = xgb_wrapper.predict(X_test)
print('xgbm 정확도: {:0.3f}'.format(accuracy_score(y_test, w_preds)))


k_model = KNeighborsClassifier(n_neighbors=40)
k_model.fit(X_train,y_train)
k_pred = k_model.predict(X_test)
k_accuracy = accuracy_score(y_test,k_pred)
print('KNN 예측 정확도: {:0.3f}'. format(k_accuracy))


svm_model = svm.SVC(kernel='rbf')
svm_model.fit(X_train, y_train)
svm_pred = svm_model.predict(X_test)
svm_accuracy = accuracy_score(y_test,svm_pred)
print('SVM 예측정확도: {:0.3f}'.format(svm_accuracy))


lr_clf = LogisticRegression()
knn_clf = KNeighborsClassifier(n_neighbors=8)
vo_clf = VotingClassifier( estimators=[('LR',lr_clf),('KNN',knn_clf)] , voting='soft' )
vo_clf.fit(X_train , y_train)
pred = vo_clf.predict(X_test)
print('Voting 분류기 정확도: {0:.3f}'.format(accuracy_score(y_test , pred)))
# Out:
# DecisionTreeClassifier 정확도: 0.637
# RandomForestClassifier 정확도: 0.720
# LogisticRegression 정확도: 0.708
# lgbm 정확도: 0.711
# xgbm 정확도: 0.717
# KNN 예측 정확도: 0.667
# SVM 예측정확도: 0.709
# Voting 분류기 정확도: 0.696
# Wall time: 28.6 s

# %%
import pandas as pd
jedf=pd.read_excel('C:/1차data/제휴사별.xlsx')
jedf
# Out:
#         고객번호 제휴사  구매횟수       총구매액  평균구매액
# 0          1   A   874   83024104  94993
# 1          1   B    64     754018  11782
# 2          1   C   119     994626   8358
# 3          2   A  1080  101191019  93695
# 4          2   B    16     207512  12970
# ...      ...  ..   ...        ...    ...
# 58626  19382   C     3       6601   2200
# 58627  19383   A    18    1091172  60621
# 58628  19383   B    16      54734   3421
# 58629  19383   C     3       9675   3225
# 58630  19383   D   223    1148830   5152
#
# [58631 rows x 5 columns]

# %%
pjedf = pd.pivot_table(jedf,
                     index = '고객번호', # 행 위치에 들어갈 열
                     columns = '제휴사', # 열 위치에 들어갈 열
                     values = ['구매횟수','총구매액','평균구매액'], # 데이터로 사용할 열
                     aggfunc = 'max') # 데이터 집계 함수
pjedf.to_csv('제휴사.csv',encoding='cp949')

#
#       C번제휴사구매비율(%) D번제휴사구매비율(%)
# 제휴사
# 고객번호
# 1             7.26         0.00
# 2             0.00         9.90
# 3             2.99         0.00
# 4            13.13         0.00
# 5             0.00        15.12
# ...            ...          ...
# 19379         3.39         8.91
# 19380         8.97        23.96
# 19381         2.71         0.00
# 19382         4.14         0.00
# 19383         4.45         7.11
#
# [19383 rows x 16 columns]

# %%
jdf=pjedf.drop(['구매횟수','총구매액','평균구매액'],axis=1)
jdf.columns=['A제휴사구매비율(%)','B제휴사구매비율(%)','C제휴사구매비율(%)','D번제휴사구매비율(%)']
jdf
# Out:
#        A제휴사구매비율(%)  B제휴사구매비율(%)  C제휴사구매비율(%)  D번제휴사구매비율(%)
# 고객번호
# 1            82.51        10.23         7.26          0.00
# 2            79.14        10.96         0.00          9.90
# 3            92.59         4.42         2.99          0.00
# 4            55.13        31.74        13.13          0.00
# 5            45.64        39.25         0.00         15.12
# ...            ...          ...          ...           ...
# 19379        73.09        14.61         3.39          8.91
# 19380        40.47        26.60         8.97         23.96
# 19381        89.22         8.07         2.71          0.00
# 19382        87.00         8.86         4.14          0.00
# 19383        83.71         4.72         4.45          7.11
#
# [19383 rows x 4 columns]

# %%
df=pd.merge(df,jdf, on='고객번호',how='left')
df
# Out:
#         고객번호  성별  연령대  거주지역  1번품목구매비율(%)  2번품목구매비율(%)  3번품목구매비율(%)  \
# 0          1   1    5     1         2.86        27.70        66.92
# 1          2   1    5     0         3.64        36.73        53.35
# 2          3   1    5     0         4.47        95.53         0.00
# 3          4   0    5     1         2.72        26.13        66.48
# 4          6   0    5     3         4.99        45.59        40.38
# ...      ...  ..  ...   ...          ...          ...          ...
# 18861  19333   0    1     0        15.53        55.08         0.00
# 18862  19334   1    2     3        13.88        66.70         0.00
# 18863  19335   0    2     0        16.72        53.31         0.00
# 18864  19336   0    2     1        10.66        30.64        54.74
# 18865  19337   1    1     1         6.46        93.54         0.00
#
#        4번품목구매비율(%)  경쟁사이용횟수  멤버쉽보유  ...  4기구매비율(%)  5기구매비율(%)  6기구매비율(%)  \
# 0             2.52     15.0    0.0  ...      14.90       8.43      10.15
# 1             6.28      8.0    0.0  ...       6.49      17.57      11.73
# 2             0.00      0.0    0.0  ...      11.11      14.96      11.62
# 3             4.67      3.0    0.0  ...      12.53       9.71       9.85
# 4             9.04      0.0    0.0  ...      11.16      12.32      14.81
# ...            ...      ...    ...  ...        ...        ...        ...
# 18861        29.39      0.0    1.0  ...       7.99      13.80      15.52
# 18862        19.42     30.0    1.0  ...      11.36      11.80       7.81
# 18863        29.97      0.0    1.0  ...       9.74      10.97      17.91
# 18864         3.96      0.0    0.0  ...      11.51       7.79      19.75
# 18865         0.00      0.0    0.0  ...      14.14      13.50      11.38
#
#        7기구매비율(%)  8기구매비율(%)  분기증감확인  A제휴사구매비율(%)  B제휴사구매비율(%)  C제휴사구매비율(%)  \
# 19383         4.45         7.11
#
# [19383 rows x 16 columns]

# %%
pjedf['14_1구매경험'] = np.where(pjedf['구매횟수']['A'>0,'유','무')
pjedf['14_2구매경험'] = np.where(pjedf['구매횟수']>0,'유','무')
pjedf['14_3구매경험'] = np.where(pjedf['구매횟수']>0,'유','무')
pjedf['14_4구매경험'] = np.where(pjedf['구매횟수']>0,'유','무')
pjedf['15_1구매경험'] = np.where(pjedf['구매횟수']>0,'유','무')
pjedf['15_2구매경험'] = np.where(pjedf['구매횟수']>0,'유','무')
pjedf['15_3구매경험'] = np.where(pjedf['구매횟수']>0,'유','무')
pjedf['15_4구매경험'] = np.where(pjedf['구매횟수']>0,'유','무')
pjedf
# Out:
#          구매횟수                               총구매액                        \
# 제휴사         A      B       C      D            A          B          C
# 고객번호
# 1       874.0   64.0   119.0    0.0   83024104.0   754018.0   994626.0
# 2      1080.0   16.0     0.0   20.0  101191019.0   207512.0        0.0
# 3         1.0    2.0  1188.0    0.0      82407.0     7863.0  3160128.0
# 4       649.0  126.0   155.0    0.0   14582805.0  1629784.0   829658.0
# 5       711.0    1.0     0.0    7.0   13018618.0    15745.0        0.0
# ...       ...    ...     ...    ...          ...        ...        ...
# 19379    33.0   29.0    22.0  500.0    1847757.0   324661.0    57121.0
# 19380     3.0    7.0    42.0  388.0      43212.0    66258.0   134049.0
# 19381     5.0  791.0     9.0    0.0     401711.0  5747363.0    21970.0
# 19382     4.0  899.0     3.0    0.0     184724.0  4227018.0     6601.0
# 19383    18.0   16.0     3.0  223.0    1091172.0    54734.0     9675.0
#
#                     평균구매액                           A번제휴사구매비율(%) B번제휴사구매비율(%)  \
# 제휴사            D        A        B       C        D
# 고객번호
# 1            0.0  94993.0  11782.0  8358.0      0.0        82.51        10.23
# 2       234491.0  93695.0  12970.0     0.0  11725.0        79.14        10.96
# 3            0.0  82407.0   3932.0  2660.0      0.0        92.59         4.42
# 4            0.0  22470.0  12935.0  5353.0      0.0        55.13        31.74
# 5        42449.0  18310.0  15745.0     0.0   6064.0        45.64        39.25
# ...          ...      ...      ...     ...      ...          ...          ...
# 19379  3411639.0  55993.0  11195.0  2596.0   6823.0        73.09        14.61
# 19380  3308377.0  14404.0   9465.0  3192.0   8527.0        40.47        26.60
# 19381        0.0  80342.0   7266.0  2441.0      0.0        89.22         8.07
# 19382        0.0  46181.0   4702.0  2200.0      0.0        87.00         8.86
# 19383  1148830.0  60621.0   3421.0  3225.0   5152.0        83.71         4.72
#
#       C번제휴사구매비율(%) D번제휴사구매비율(%) A구매경험 B구매경험 C구매경험 D구매경험
# 제휴사
# 고객번호
# 1             7.26         0.00     유     유     유     무
# 2             0.00         9.90     유     유     무     유
# 3             2.99         0.00     유     유     유     무
# 4            13.13         0.00     유     유     유     무
# 5             0.00        15.12     유     유     무     유
# ...            ...          ...   ...   ...   ...   ...
# 19379         3.39         8.91     유     유     유     유
# 19380         8.97        23.96     유     유     유     유
