# %%
import pandas as pd
file_data = pd.read_csv('file_data.csv')
file_data['가격'] = [5000,5000,4000,5000,3000]
file_data
# Out:
#     차림표    가격
# 0    냉면  5000
# 1   칼국수  5000
# 2  잔치국수  4000
# 3   수제비  5000
# 4    우동  3000

# %%
df1 = file_data.copy()
df2 = pd.DataFrame({
    '차림표':['비빔밥','돈까스','라면','김밥','제육덮밥'],
    '가격':[7000,8000,3000,3000,9000]
})
df2
# Out:
#     차림표    가격
# 0   비빔밥  7000
# 1   돈까스  8000
# 2    라면  3000
# 3    김밥  3000
# 4  제육덮밥  9000

# %%
# 병합 - 세로방향
dfc1 = pd.concat([df1,df2])
dfc1
# Out:
#     차림표    가격
# 0    냉면  5000
# 1   칼국수  5000
# 2  잔치국수  4000
# 3   수제비  5000
# 4    우동  3000
# 0   비빔밥  7000
# 1   돈까스  8000
# 2    라면  3000
# 3    김밥  3000
# 4  제육덮밥  9000

# %%
# 병합 - 가로방향
dfc2 = pd.concat([df1,df2],axis=1)
dfc2
# Out:
#     차림표    가격   차림표    가격
# 0    냉면  5000   비빔밥  7000
# 1   칼국수  5000   돈까스  8000
# 2  잔치국수  4000    라면  3000
# 3   수제비  5000    김밥  3000
# 4    우동  3000  제육덮밥  9000

# %%
new_column = ['메뉴1','가격1','메뉴2','가격2']
dfc2.columns = new_column
dfc2
# Out:
#     메뉴1   가격1   메뉴2   가격2
# 0    냉면  5000   비빔밥  7000
# 1   칼국수  5000   돈까스  8000
# 2  잔치국수  4000    라면  3000
# 3   수제비  5000    김밥  3000
# 4    우동  3000  제육덮밥  9000

# %%
sr1 = dfc2['메뉴1']
sr2 = dfc2['가격2']
print(sr1,'\n')
print(sr2)
type(sr2)
# Out:
# 0      냉면
# 1     칼국수
# 2    잔치국수
# 3     수제비
# 4      우동
# Name: 메뉴1, dtype: object
#
# 0    7000
# 1    8000
# 2    3000
# 3    3000
# 4    9000
# Name: 가격2, dtype: int64
# pandas.core.series.Series

# %%
# 시리즈 -> 데이터프레임
df = pd.concat([sr1,sr2],axis=1)
df
# Out:
#     메뉴1   가격2
# 0    냉면  7000
# 1   칼국수  8000
# 2  잔치국수  3000
# 3   수제비  3000
# 4    우동  9000

# %%
# 열 삭제, inplace=True는 원본에 반영함을 의미 
dfc3 = dfc2.copy()
dfc3.drop(['가격1','가격2'],axis=1,inplace=True)
# dfc3.drop(['가격1','가격2'],axis=1)
dfc3
# Out:
#     메뉴1   메뉴2
# 0    냉면   비빔밥
# 1   칼국수   돈까스
# 2  잔치국수    라면
# 3   수제비    김밥
# 4    우동  제육덮밥

# %%
# 행 삭제
dfc3.drop([0,1],axis=0,inplace=True)
dfc3
# Out:
#     메뉴1   메뉴2
# 2  잔치국수    라면
# 3   수제비    김밥
# 4    우동  제육덮밥

# %%
dfc3 = dfc2.copy()
dfc3
# Out:
#     메뉴1   가격1   메뉴2   가격2
# 0    냉면  5000   비빔밥  7000
# 1   칼국수  5000   돈까스  8000
# 2  잔치국수  4000    라면  3000
# 3   수제비  5000    김밥  3000
# 4    우동  3000  제육덮밥  9000

# %%
# [과제] 인덱싱을 이용하여 특정 컬럼, 특정 행, 특정 값을 추출

# %%
# 조건(하나 또는 복수)에 맞는 데이터 추출 - 불린인덱싱
dfc3.loc[dfc3['가격1']>4500,['메뉴1','가격1']]
# Out:
#    메뉴1   가격1
# 0   냉면  5000
# 1  칼국수  5000
# 3  수제비  5000

# %%
# [과제] 행, 열 모두에 조건 지정

# %%
# 행 추가
dfc3.loc[5] = ['김치라면', '4000', '만두', '5000']
dfc3
# Out:
#     메뉴1   가격1   메뉴2   가격2
# 0    냉면  5000   비빔밥  7000
# 1   칼국수  5000   돈까스  8000
# 2  잔치국수  4000    라면  3000
# 3   수제비  5000    김밥  3000
# 4    우동  3000  제육덮밥  9000
# 5  김치라면  4000    만두  5000

# %%
# 열 추가 
dfc3['메뉴3'] = dfc3.메뉴2
dfc3
# Out:
#     메뉴1   가격1   메뉴2   가격2   메뉴3
# 0    냉면  5000   비빔밥  7000   비빔밥
# 1   칼국수  5000   돈까스  8000   돈까스
# 2  잔치국수  4000    라면  3000    라면
# 3   수제비  5000    김밥  3000    김밥
# 4    우동  3000  제육덮밥  9000  제육덮밥
# 5  김치라면  4000    만두  5000    만두

# %%
dfc1
# Out:
#     차림표    가격
# 0    냉면  5000
# 1   칼국수  5000
# 2  잔치국수  4000
# 3   수제비  5000
# 4    우동  3000
# 0   비빔밥  7000
# 1   돈까스  8000
# 2    라면  3000
# 3    김밥  3000
# 4  제육덮밥  9000

# %%
# 인덱시 재정렬
ndf = dfc1.reset_index()
ndf.drop('index',axis=1,inplace=True)
ndf
# Out:
#     차림표    가격
# 0    냉면  5000
# 1   칼국수  5000
# 2  잔치국수  4000
# 3   수제비  5000
# 4    우동  3000
# 5   비빔밥  7000
# 6   돈까스  8000
# 7    라면  3000
# 8    김밥  3000
# 9  제육덮밥  9000

# %%
ndf1 = ndf.copy()
ndf1
# Out:
#     차림표    가격
# 0    냉면  5000
# 1   칼국수  5000
# 2  잔치국수  4000
# 3   수제비  5000
# 4    우동  3000
# 5   비빔밥  7000
# 6   돈까스  8000
# 7    라면  3000
# 8    김밥  3000
# 9  제육덮밥  9000

# %%
# 인덱스 설정
ndf1.index=np.arange(1,11)
ndf1
# Out:
#      차림표    가격
# 1     냉면  5000
# 2    칼국수  5000
# 3   잔치국수  4000
# 4    수제비  5000
# 5     우동  3000
# 6    비빔밥  7000
# 7    돈까스  8000
# 8     라면  3000
# 9     김밥  3000
# 10  제육덮밥  9000

# %%
import numpy as np
# 인덱스 지정한 데로 설정 : reindex
new_index = np.arange(1,15)
ndf2 = ndf1.reindex(new_index,fill_value=1)
ndf2
# Out:
#      차림표    가격
# 1     냉면  5000
# 2    칼국수  5000
# 3   잔치국수  4000
# 4    수제비  5000
# 5     우동  3000
# 6    비빔밥  7000
# 7    돈까스  8000
# 8     라면  3000
# 9     김밥  3000
# 10  제육덮밥  9000
# 11     1     1
# 12     1     1
# 13     1     1
# 14     1     1

# %%
# 내림차순 정렬
ndf2 = ndf1.sort_index(ascending=False)
ndf2
# Out:
#      차림표    가격
# 10  제육덮밥  9000
# 9     김밥  3000
# 8     라면  3000
# 7    돈까스  8000
# 6    비빔밥  7000
# 5     우동  3000
# 4    수제비  5000
# 3   잔치국수  4000
# 2    칼국수  5000
# 1     냉면  5000

# %%
ndf3 = ndf2.sort_index(ascending=True)
ndf3
# Out:
#      차림표    가격
# 1     냉면  5000
# 2    칼국수  5000
# 3   잔치국수  4000
# 4    수제비  5000
# 5     우동  3000
# 6    비빔밥  7000
# 7    돈까스  8000
# 8     라면  3000
# 9     김밥  3000
# 10  제육덮밥  9000

# %%
ndf4 = ndf2.sort_values(by='가격',ascending=False)
ndf4
# Out:
#      차림표    가격
# 9     김밥  3000
# 8     라면  3000
# 5     우동  3000
# 3   잔치국수  4000
# 4    수제비  5000
# 2    칼국수  5000
# 1     냉면  5000
# 6    비빔밥  7000
# 7    돈까스  8000
# 10  제육덮밥  9000

# %%
import numpy as np
columns = ['kor','eng','art','math','gym','sci']
index = ['jim','sam','tom','tim','bob']
data = np.random.randint(70,100,size=(5,6))
df = pd.DataFrame(data,index,columns=columns)
df
# Out:
#      kor  eng  art  math  gym  sci
# jim   93   87   71    88   98   92
# sam   95   93   74    76   83   70
# tom   84   82   79    88   70   87
# tim   92   81   98    90   92   76
# bob   85   76   75    99   79   98

# %% [markdown]
# [과제] iloc, loc를 이용해서 아래 요구사항들을 출력하세요
# - df의 kor열을 series와 dataframe을 각각 출력
# - df에서 sam의 math 점수를 출력(2가지 방법)
# - df에서 tom의 eng와 sci 점수를 출력(2가지 방법)
# - df에서 jim, tim의 eng, gym 점수를 출력
# - df에서 jim, sam의 art,math,gym 점수를 출력

# %%
df['kor']

# %%
df[['kor']]

# %%
df.loc[['sam'],['math']]
# Out:
#      math
# sam    76

# %%
df.loc['sam','math']
# Out:
# 76

# %%
df.loc['tom',['eng','sci']]
# Out:
# math    88
# sci     87
# Name: tom, dtype: int32

# %%
df.loc[['tom'],['eng','sci']]
# Out:
#      math  sci
# tom    88   87

# %%
df.loc[['jim','tim'],['eng','gym']]
# Out:
#      eng  gym
# jim   87   98
# tim   81   92

# %%
df.loc[['jim','sam'],['art','math','gym']]
# Out:
#      art  math  gym
# jim   71    88   98
# sam   74    76   83

# %% [markdown]
# [과제] iloc, loc를 이용해서 아래 요구사항들을 수행하세요
# - df에서 sam의 math 점수를 100으로 변경
# - df에서 tom의 eng와 math 점수를 100으로 변경
# - df에서 jim, tim의 kor, gym 점수를 null값으로 변경
# - df에서 math와 gym 점수를 바꾸어 출력

# %%
df.loc['sam','math']=100
df.loc[['sam'],['math']]
# Out:
#      math
# sam   100

# %%
df.loc['tom',['eng','math']]=100
df.loc[['tom'],['eng','math']]
# Out:
#      eng  math
# tom  100   100

# %%
df.loc[['jim','tim'],['kor','gym']]=np.nan
df.loc[['jim','tim'],['kor','gym']]
# Out:
#      kor  gym
# jim  NaN  NaN
# tim  NaN  NaN

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\admin\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\admin\anaconda3\lib\site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\admin\anaconda3\lib\site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\admin\anaconda3\lib\site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: six in c:\users\admin\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)

# %%
import seaborn as sns
df = sns.load_dataset('titanic')
df.columns #컬럼만추출
df.insert(5,'family',df['sibsp']+df['parch']) #병합
df= df.drop(['sibsp','parch'],axis=1) #삭제
df=df.replace(['male'],'man')#변경
df=df.sort_values(by='family',ascending=False)#정렬
df=df.iloc[10:20]#인덱싱추출

df
# Out:
#      survived  pclass     sex   age  family     fare embarked  class    who  \
# 683         0       3     man  14.0       7  46.9000        S  Third  child
# 480         0       3     man   9.0       7  46.9000        S  Third  child
# 71          0       3  female  16.0       7  46.9000        S  Third  woman
# 119         0       3  female   2.0       6  31.2750        S  Third  child
# 610         0       3  female  39.0       6  31.2750        S  Third  woman
# 261         1       3     man   3.0       6  31.3875        S  Third  child
# 233         1       3  female   5.0       6  31.3875        S  Third  child
# 813         0       3  female   6.0       6  31.2750        S  Third  child
# 68          1       3  female  17.0       6   7.9250        S  Third  woman
# 25          1       3  female  38.0       6  31.3875        S  Third  woman
#
#      adult_male deck  embark_town alive  alone
# 683       False  NaN  Southampton    no  False
# 480       False  NaN  Southampton    no  False
# 71        False  NaN  Southampton    no  False
# 119       False  NaN  Southampton    no  False
# 610       False  NaN  Southampton    no  False
# 261       False  NaN  Southampton   yes  False
# 233       False  NaN  Southampton   yes  False
# 813       False  NaN  Southampton    no  False
# 68        False  NaN  Southampton   yes  False
# 25        False  NaN  Southampton   yes  False

# %%
# [과제] 데이터 추출(인덱싱, 조건), 변경, 삭제, 정렬, 칼럼 병합(sibsp + parch = family) 등을 수행하여 데이터에서 인사이트를 찾아보세요
